# %% [markdown]
# # Verification Curves

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
import os
import xarray as xr
from src.constants import DATA_PATH

# %%
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset(os.path.join(DATA_PATH, "emulation_angle_pos_Mattern32", "data.nc"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (inum: 100, var: 2, anum: 30)
# Coordinates:
#   * var       (var) object 'x1' 'x2'
# Dimensions without coordinates: inum, anum
# Data variables:
#     init_x    (inum, var) float32 ...
#     init_y    (inum) float64 ...
#     active_x  (anum, var) float64 ...
#     active_y  (anum) float64 ...
# Attributes:
#     description:  Training Data

# %%
plt.plot(ds["active_y"])
plt.xlabel("Active Number")
plt.ylabel("New Height [m]")
# Out:
# Text(0, 0.5, 'New Height [m]')

# %%
plt.plot(ds["init_y"])
plt.xlabel("Initial Number")
plt.ylabel("New Height [m]")
# Out:
# Text(0, 0.5, 'New Height [m]')
