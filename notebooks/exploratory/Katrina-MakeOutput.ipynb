# %% [markdown]
# # Katrina New Input Files

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
import os
import xarray as xr
import matplotlib.pyplot as plt
import adcircpy
from adcircpy.outputs import (
    Maxele,
    MaximumElevationTimes,
    Fort63,
    Fort61,
    Minpr,
    Maxwvel,
    Maxvel,
)
from sithom.plot import plot_defaults
from src.constants import KAT_EX_PATH, NO_BBOX, DATA_PATH

plot_defaults()
# Out:
# /Users/simon/new-orleans/env/lib/python3.8/site-packages/xarray/backends/cfgrib_.py:29: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(
# /Users/simon/new-orleans/env/lib/python3.8/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(

# %%
da = xr.open_dataarray(os.path.join(DATA_PATH, "fort.221.nc"))

# %%
da
# Out:
# <xarray.DataArray (time: 56, lat: 100, lon: 100)>
# [560000 values with dtype=float64]
# Coordinates:
#   * lon      (lon) float64 -99.0 -98.75 -98.5 -98.25 ... -74.75 -74.5 -74.25
#   * lat      (lat) float64 17.0 17.25 17.5 17.75 18.0 ... 41.0 41.25 41.5 41.75
#   * time     (time) float64 2.005e+11 2.005e+11 ... 2.005e+11 2.005e+11
# Attributes:
#     description:  Pressure
#     long_name:    Pressure
#     units:        mb

# %%
date_str = str(da.time.values.astype("int")[0])

# %%
date_str
# Out:
# '200508250000'

# %%
import numpy as np
import datetime


@np.vectorize
def int_to_datetime(int_input: int) -> datetime.datetime:
    """ """
    date_str = str(int_input)
    return datetime.datetime(
        year=int(date_str[:4]),
        month=int(date_str[4:6]),
        day=int(date_str[6:8]),
        hour=int(date_str[8:10]),
        minute=int(date_str[10:12]),
    )


def two_char_int(int_input: int) -> str:
    """
    Two char int.

    Args:
        int_input (int): input integer.

    Returns:
        str: Two char int.
    """
    ret_str = str(int_input)
    if len(ret_str) == 1:
        ret_str = "0" + ret_str
    return ret_str


@np.vectorize
def datetime_to_int(date: datetime.datetime) -> int:
    return int(
        str(date.year)
        + two_char_int(date.month)
        + two_char_int(date.day)
        + two_char_int(date.hour)
        + two_char_int(date.minute)
    )


date_output = int_to_datetime(da.time.values.astype("int"))
int_output = datetime_to_int(date_output)
date_output_2 = int_to_datetime(int_output)

# %%
int_output
# Out:
# array([2005080000, 2005080300, 2005080600, 2005080900, 2005081200,
#        2005081500, 2005081800, 2005082100, 2005080000, 2005080300,
#        2005080600, 2005080900, 2005081200, 2005081500, 2005081800,
#        2005082100, 2005080000, 2005080300, 2005080600, 2005080900,
#        2005081200, 2005081500, 2005081800, 2005082100, 2005080000,
#        2005080300, 2005080600, 2005080900, 2005081200, 2005081500,
#        2005081800, 2005082100, 2005080000, 2005080300, 2005080600,
#        2005080900, 2005081200, 2005081500, 2005081800, 2005082100,
#        2005080000, 2005080300, 2005080600, 2005080900, 2005081200,
#        2005081500, 2005081800, 2005082100, 2005080000, 2005080300,
#        2005080600, 2005080900, 2005081200, 2005081500, 2005081800,
#        2005082100])

# %%
print(date_output)
# Out:
# [datetime.datetime(2005, 8, 25, 0, 0) datetime.datetime(2005, 8, 25, 3, 0)
#  datetime.datetime(2005, 8, 25, 6, 0) datetime.datetime(2005, 8, 25, 9, 0)
#  datetime.datetime(2005, 8, 25, 12, 0)
#  datetime.datetime(2005, 8, 25, 15, 0)
#  datetime.datetime(2005, 8, 25, 18, 0)
#  datetime.datetime(2005, 8, 25, 21, 0)
#  datetime.datetime(2005, 8, 26, 0, 0) datetime.datetime(2005, 8, 26, 3, 0)
#  datetime.datetime(2005, 8, 26, 6, 0) datetime.datetime(2005, 8, 26, 9, 0)
#  datetime.datetime(2005, 8, 26, 12, 0)
#  datetime.datetime(2005, 8, 26, 15, 0)
#  datetime.datetime(2005, 8, 26, 18, 0)
#  datetime.datetime(2005, 8, 26, 21, 0)
#  datetime.datetime(2005, 8, 27, 0, 0) datetime.datetime(2005, 8, 27, 3, 0)
#  datetime.datetime(2005, 8, 27, 6, 0) datetime.datetime(2005, 8, 27, 9, 0)
#  datetime.datetime(2005, 8, 27, 12, 0)
#  datetime.datetime(2005, 8, 27, 15, 0)
#  datetime.datetime(2005, 8, 27, 18, 0)
#  datetime.datetime(2005, 8, 27, 21, 0)
#  datetime.datetime(2005, 8, 28, 0, 0) datetime.datetime(2005, 8, 28, 3, 0)
#  datetime.datetime(2005, 8, 28, 6, 0) datetime.datetime(2005, 8, 28, 9, 0)
#  datetime.datetime(2005, 8, 28, 12, 0)
#  datetime.datetime(2005, 8, 28, 15, 0)
#  datetime.datetime(2005, 8, 28, 18, 0)
#  datetime.datetime(2005, 8, 28, 21, 0)
#  datetime.datetime(2005, 8, 29, 0, 0) datetime.datetime(2005, 8, 29, 3, 0)
#  datetime.datetime(2005, 8, 29, 6, 0) datetime.datetime(2005, 8, 29, 9, 0)
#  datetime.datetime(2005, 8, 29, 12, 0)
#  datetime.datetime(2005, 8, 29, 15, 0)
#  datetime.datetime(2005, 8, 29, 18, 0)
#  datetime.datetime(2005, 8, 29, 21, 0)
#  datetime.datetime(2005, 8, 30, 0, 0) datetime.datetime(2005, 8, 30, 3, 0)
#  datetime.datetime(2005, 8, 30, 6, 0) datetime.datetime(2005, 8, 30, 9, 0)
#  datetime.datetime(2005, 8, 30, 12, 0)
#  datetime.datetime(2005, 8, 30, 15, 0)
#  datetime.datetime(2005, 8, 30, 18, 0)
#  datetime.datetime(2005, 8, 30, 21, 0)
#  datetime.datetime(2005, 8, 31, 0, 0) datetime.datetime(2005, 8, 31, 3, 0)
#  datetime.datetime(2005, 8, 31, 6, 0) datetime.datetime(2005, 8, 31, 9, 0)
#  datetime.datetime(2005, 8, 31, 12, 0)
#  datetime.datetime(2005, 8, 31, 15, 0)
#  datetime.datetime(2005, 8, 31, 18, 0)
#  datetime.datetime(2005, 8, 31, 21, 0)]

# %%
print(date_output_2)
# Out:
# [datetime.datetime(2005, 8, 25, 0, 0) datetime.datetime(2005, 8, 25, 3, 0)
#  datetime.datetime(2005, 8, 25, 6, 0) datetime.datetime(2005, 8, 25, 9, 0)
#  datetime.datetime(2005, 8, 25, 12, 0)
#  datetime.datetime(2005, 8, 25, 15, 0)
#  datetime.datetime(2005, 8, 25, 18, 0)
#  datetime.datetime(2005, 8, 25, 21, 0)
#  datetime.datetime(2005, 8, 26, 0, 0) datetime.datetime(2005, 8, 26, 3, 0)
#  datetime.datetime(2005, 8, 26, 6, 0) datetime.datetime(2005, 8, 26, 9, 0)
#  datetime.datetime(2005, 8, 26, 12, 0)
#  datetime.datetime(2005, 8, 26, 15, 0)
#  datetime.datetime(2005, 8, 26, 18, 0)
#  datetime.datetime(2005, 8, 26, 21, 0)
#  datetime.datetime(2005, 8, 27, 0, 0) datetime.datetime(2005, 8, 27, 3, 0)
#  datetime.datetime(2005, 8, 27, 6, 0) datetime.datetime(2005, 8, 27, 9, 0)
#  datetime.datetime(2005, 8, 27, 12, 0)
#  datetime.datetime(2005, 8, 27, 15, 0)
#  datetime.datetime(2005, 8, 27, 18, 0)
#  datetime.datetime(2005, 8, 27, 21, 0)
#  datetime.datetime(2005, 8, 28, 0, 0) datetime.datetime(2005, 8, 28, 3, 0)
#  datetime.datetime(2005, 8, 28, 6, 0) datetime.datetime(2005, 8, 28, 9, 0)
#  datetime.datetime(2005, 8, 28, 12, 0)
#  datetime.datetime(2005, 8, 28, 15, 0)
#  datetime.datetime(2005, 8, 28, 18, 0)
#  datetime.datetime(2005, 8, 28, 21, 0)
#  datetime.datetime(2005, 8, 29, 0, 0) datetime.datetime(2005, 8, 29, 3, 0)
#  datetime.datetime(2005, 8, 29, 6, 0) datetime.datetime(2005, 8, 29, 9, 0)
#  datetime.datetime(2005, 8, 29, 12, 0)
#  datetime.datetime(2005, 8, 29, 15, 0)
#  datetime.datetime(2005, 8, 29, 18, 0)
#  datetime.datetime(2005, 8, 29, 21, 0)
#  datetime.datetime(2005, 8, 30, 0, 0) datetime.datetime(2005, 8, 30, 3, 0)
#  datetime.datetime(2005, 8, 30, 6, 0) datetime.datetime(2005, 8, 30, 9, 0)
#  datetime.datetime(2005, 8, 30, 12, 0)
#  datetime.datetime(2005, 8, 30, 15, 0)
#  datetime.datetime(2005, 8, 30, 18, 0)
#  datetime.datetime(2005, 8, 30, 21, 0)
#  datetime.datetime(2005, 8, 31, 0, 0) datetime.datetime(2005, 8, 31, 3, 0)
#  datetime.datetime(2005, 8, 31, 6, 0) datetime.datetime(2005, 8, 31, 9, 0)
#  datetime.datetime(2005, 8, 31, 12, 0)
#  datetime.datetime(2005, 8, 31, 15, 0)
#  datetime.datetime(2005, 8, 31, 18, 0)
#  datetime.datetime(2005, 8, 31, 21, 0)]
